# %%
import shutil
import os

# %%
file = open("filenames.txt")
data = file.readlines()

# %%
len(data)
# Out:
# 5416

# %%
for i in range(0,5416):
    data[i] = data[i].replace("\n","")
    data[i] = data[i].replace(" ","")

# %%
data
# Out:
# ['923359375346_VXT_Mufti_IVR_Q_20220408234754.wav',
#  '923355830601_VXT_Mufti_IVR_Q_20220409011709.wav',
#  '923333265039_VXT_Mufti_IVR_Q_20220409060213.wav',
#  '923355131619_VXT_Mufti_IVR_Q_20220409070825.wav',
#  '923334886175_VXT_Mufti_IVR_Q_20220409080215.wav',
#  '923334886175_VXT_Mufti_IVR_Q_20220409080627.wav',
#  '923334886175_VXT_Mufti_IVR_Q_20220409080948.wav',
#  '923334886175_VXT_Mufti_IVR_Q_20220409081056.wav',
#  '923334886175_VXT_Mufti_IVR_Q_20220409083025.wav',
#  '923333009529_VXT_Mufti_IVR_Q_20220409085719.wav',
#  '923330125221_VXT_Mufti_IVR_Q_20220409095513.wav',
#  '923302893419_VXT_Mufti_IVR_Q_20220403013553.wav',
#  '923373122493_VXT_Mufti_IVR_Q_20220403032031.wav',
#  '923373122493_VXT_Mufti_IVR_Q_20220403032220.wav',
#  '923373122493_VXT_Mufti_IVR_Q_20220403032425.wav',
#  '923373122493_VXT_Mufti_IVR_Q_20220403033303.wav',
#  '923346907807_VXT_Mufti_IVR_Q_20220403042201.wav',
#  '923341638090_VXT_Mufti_IVR_Q_20220403042754.wav',
# ...

# %%
orig_path = "/home/ammar/Desktop/mustanad_jawab/assets/Mufti_Folder/MUFTI_QUESTIONS"
copy_path = "/home/ammar/Desktop/mustanad_jawab/assets/audio_classifier_data/accepted"
files = os.listdir(orig_path)

# %%
for file in files:
    if file in data:
        print(file)
        shutil.copy(os.path.join(orig_path,file),copy_path)
# Out:
# 923138734443_VXT_Khwab_IVR_Q_20220822130729.wav
# 923145348816_VXT_Khwab_IVR_Q_20220828143501.wav
# 923154275963_VXT_Mufti_IVR_Q_20221103165253.wav
# 923175135298_VXT_Mufti_IVR_Q_20220418175329.wav
# 923172533943_VXT_Mufti_IVR_Q_20220718195646.wav
# 923143133519_VXT_Mufti_IVR_Q_20220718201830.wav
# 923139565964_VXT_Mufti_IVR_Q_20220703002524.wav
# 923174074047_VXT_Khwab_IVR_Q_20220707164859.wav
# 923196329411_VXT_Mufti_IVR_Q_20220830103448.wav
# 923124719054_VXT_Khwab_IVR_Q_20220607091617.wav
# 923100274421_VXT_Khwab_IVR_Q_20220821000515.wav
# 923197506384_VXT_Khwab_IVR_Q_20220709121705.wav
# 923139450016_VXT_Khwab_IVR_Q_20220730092558.wav
# 923179226865_VXT_Mufti_IVR_Q_20220405150321.wav
# 923188491034_VXT_Mufti_IVR_Q_20220513104437.wav
# 923162141607_VXT_Khwab_IVR_Q_20221020111733.wav
# 923117536682_VXT_Mufti_IVR_Q_20221125202649.wav
# 923102668879_VXT_Mufti_IVR_Q_20220422111450.wav
# 923115066729_VXT_Khwab_IVR_Q_20220726115659.wav
# 923151744047_VXT_Mufti_IVR_Q_20221127175638.wav
# ...
